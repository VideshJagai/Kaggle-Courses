# %% [markdown]
# **This notebook is an exercise in the [Pandas](https://www.kaggle.com/learn/pandas) course.  You can reference the tutorial at [this link](https://www.kaggle.com/residentmario/data-types-and-missing-values).**
#
# ---

# %% [markdown]
# # Introduction
#
# Run the following cell to load your data and some utility functions.

# %%
import pandas as pd

reviews = pd.read_csv("../input/wine-reviews/winemag-data-130k-v2.csv", index_col=0)

from learntools.core import binder; binder.bind(globals())
from learntools.pandas.data_types_and_missing_data import *
print("Setup complete.")
# Out:
# Setup complete.

# %% [markdown]
# # Exercises

# %% [markdown]
# ## 1.
# What is the data type of the `points` column in the dataset?

# %%
dtype = reviews.dtypes.points
dtype
# Out:
# dtype('int64')

# %%
# Your code here
dtype 

# Check your answer
q1.check()
# Out:
# Correct

# %%
#q1.hint()
#q1.solution()

# %% [markdown]
# ## 2.
# Create a Series from entries in the `points` column, but convert the entries to strings. Hint: strings are `str` in native Python.

# %%
# Entries in the points column, but convert the entries to strings.
point_strings  = reviews.points.astype('str') 
point_strings
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: object

# %%
point_strings 

# Check your answer
q2.check()
# Out:
# Correct

# %%
#q2.hint()
#q2.solution()

# %% [markdown]
# ## 3.
# Sometimes the price column is null. How many reviews in the dataset are missing a price?

# %%
## The price column is null. Many reviews are in the dataset are missing a price.
n_missing_prices=reviews.price.isna().sum()
#n_missing_prices

# %%
# Express the following rows which aligned in missing price dataset accordingly.
reviews[pd.isna(reviews.price)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 13         Italy  This is dominated by oak and oak-driven aromas...
# 30        France  Red cherry fruit comes laced with light tannin...
# 31         Italy  Merlot and Nero d'Avola form the base for this...
# 32         Italy  Part of the extended Calanìca series, this Gri...
# ...          ...                                                ...
# 129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860  Portugal  This rich wine has a firm structure as well as...
# 129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964    France  Initially quite muted, this wine slowly develo...
#
#                          designation  points  price           province  \
# 0                       Vulkà Bianco      87    NaN  Sicily & Sardinia
# ...

# %%
n_missing_prices

# Check your answer
q3.check()
# Out:
# Correct

# %%
#q3.hint()
#q3.solution()

# %% [markdown]
# ## 4.
# What are the most common wine-producing regions? Create a Series counting the number of times each value occurs in the `region_1` field. This field is often missing data, so replace missing values with `Unknown`. Sort in descending order.  Your output should look something like this:
#
# ```
# Unknown                    21247
# Napa Valley                 4480
#                            ...
# Bardolino Superiore            1
# Primitivo del Tarantino        1
# Name: region_1, Length: 1230, dtype: int64
# ```

# %%
reviews.region_1.fillna("Unkown")
# Out:
# 0                        Etna
# 1                      Unkown
# 2           Willamette Valley
# 3         Lake Michigan Shore
# 4           Willamette Valley
#                  ...
# 129966                 Unkown
# 129967                 Oregon
# 129968                 Alsace
# 129969                 Alsace
# 129970                 Alsace
# Name: region_1, Length: 129971, dtype: object

# %%
reviews_per_region = reviews.fillna("Unknown").region_1.value_counts().sort_values(ascending=False)
reviews_per_region
# Out:
# region_1
# Unknown                 21247
# Napa Valley              4480
# Columbia Valley (WA)     4124
# Russian River Valley     3091
# California               2629
#                         ...
# Offida Rosso                1
# Corton Perrières            1
# Isle St. George             1
# Geelong                     1
# Paestum                     1
# Name: count, Length: 1230, dtype: int64

# %%
reviews_per_region

# Check your answer
q4.check()
# Out:
# Correct

# %%
#q4.hint()
#q4.solution()

# %% [markdown]
# # Keep going
#
# Move on to **[renaming and combining](https://www.kaggle.com/residentmario/renaming-and-combining)**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/pandas/discussion) to chat with other learners.*
